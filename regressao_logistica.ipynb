# %%
import numpy as np
import csv

# %%
# ========================
# 1. Leitura do CSV
# ========================

def load_data(filenema):
    X = []
    Y = []

    with open(filename, "r", encoding="utf-8")
